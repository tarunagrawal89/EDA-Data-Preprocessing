# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('titanic_train.csv')

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
len(df)
# Out:
# 891

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived', hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived', hue='Pclass',data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.distplot(df['Age'].dropna(),kde=True, bins=50)
# Out:
# /Library/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.countplot(x='SibSp',data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
sns.distplot(df['Fare'].dropna(),kde=False, bins=50, color='green')
# Out:
# /Library/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare'>

# %%
from sklearn.impute import SimpleImputer

# %%
x = df.iloc[:,0:].values

# %%
print(x[0])
# Out:
# [1 0 3 'Braund, Mr. Owen Harris' 'male' 22.0 1 0 'A/5 21171' 7.25 nan 'S']

# %%
SI = SimpleImputer(missing_values=np.nan, strategy='mean')
SI.fit(x[:,5:6])
x[:,5:6]= SI.transform(x[:,5:6])

# %%
print(x[:,5:6])
# Out:
# [[22.0]
#  [38.0]
#  [26.0]
#  [35.0]
#  [35.0]
#  [29.69911764705882]
#  [54.0]
#  [2.0]
#  [27.0]
#  [14.0]
#  [4.0]
#  [58.0]
#  [20.0]
#  [39.0]
#  [14.0]
#  [55.0]
#  [2.0]
#  [29.69911764705882]
#  [31.0]
#  [29.69911764705882]
#  [35.0]
#  [34.0]
#  [15.0]
#  [28.0]
#  [8.0]
#  [38.0]
#  [29.69911764705882]
#  [19.0]
#  [29.69911764705882]
#  [29.69911764705882]
#  [40.0]
#  [29.69911764705882]
#  [29.69911764705882]
#  [66.0]
#  [28.0]
#  [42.0]
#  [29.69911764705882]
#  [21.0]
#  [18.0]
#  [14.0]
#  [40.0]
#  [27.0]
#  [29.69911764705882]
#  [3.0]
#  [19.0]
#  [29.69911764705882]
#  [29.69911764705882]
#  [29.69911764705882]
#  [29.69911764705882]
#  [18.0]
#  [7.0]
#  [21.0]
#  [49.0]
#  [29.0]
#  [65.0]
#  [29.69911764705882]
#  [21.0]
#  [28.5]
#  [5.0]
#  [11.0]
#  [22.0]
#  [38.0]
#  [45.0]
#  [4.0]
#  [29.69911764705882]
#  [29.69911764705882]
#  [29.0]
#  [19.0]
#  [17.0]
#  [26.0]
#  [32.0]
#  [16.0]
#  [21.0]
#  [26.0]
#  [32.0]
#  [25.0]
#  [29.69911764705882]
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.drop('Cabin', axis=1,inplace=True)

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Pclass',y='Age', data=df, palette='winter')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
def impute_age(cols):
    Age= cols[0]
    Pclass = cols[1]
    if pd.isnull(Age):
        if Pclass==1:
            return 37
        elif Pclass==2:
            return 29
        else:
            return 24
    else:
        return Age

# %%
df['Age']= df[['Age','Pclass']].apply(impute_age, axis=1)

# %%
print(df['Age'].values)
# Out:
# [22.   38.   26.   35.   35.   24.   54.    2.   27.   14.    4.   58.
#  20.   39.   14.   55.    2.   29.   31.   24.   35.   34.   15.   28.
#   8.   38.   24.   19.   24.   24.   40.   37.   24.   66.   28.   42.
#  24.   21.   18.   14.   40.   27.   24.    3.   19.   24.   24.   24.
#  24.   18.    7.   21.   49.   29.   65.   37.   21.   28.5   5.   11.
#  22.   38.   45.    4.   37.   24.   29.   19.   17.   26.   32.   16.
#  21.   26.   32.   25.   24.   24.    0.83 30.   22.   29.   24.   28.
#  17.   33.   16.   24.   23.   24.   29.   20.   46.   26.   59.   24.
#  71.   23.   34.   34.   28.   24.   21.   33.   37.   28.   21.   24.
#  38.   24.   47.   14.5  22.   20.   17.   21.   70.5  29.   24.    2.
#  21.   24.   32.5  32.5  54.   12.   24.   24.   24.   45.   33.   20.
#  47.   29.   25.   23.   19.   37.   16.   24.   24.   22.   24.   19.
#  18.   19.   27.    9.   36.5  42.   51.   22.   55.5  40.5  24.   51.
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.drop(['Name','Ticket','PassengerId'],axis=1)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  24.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
pd.get_dummies(df['Embarked'], drop_first=True)
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [891 rows x 2 columns]

# %%
embark = pd.get_dummies(df['Embarked'], drop_first=True)

# %%
pd.get_dummies(df['Sex'], drop_first=True)
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
sex = pd.get_dummies(df['Sex'], drop_first=True)

# %%
df.drop(['Sex','Embarked','Name','Ticket','PassengerId'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500

# %%
df = pd.concat([df,sex,embark], axis=1)

# %%
df.head(20)
# Out:
#     Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0          0       3  22.0      1      0   7.2500     1  0  1
# 1          1       1  38.0      1      0  71.2833     0  0  0
# 2          1       3  26.0      0      0   7.9250     0  0  1
# 3          1       1  35.0      1      0  53.1000     0  0  1
# 4          0       3  35.0      0      0   8.0500     1  0  1
# 5          0       3  24.0      0      0   8.4583     1  1  0
# 6          0       1  54.0      0      0  51.8625     1  0  1
# 7          0       3   2.0      3      1  21.0750     1  0  1
# 8          1       3  27.0      0      2  11.1333     0  0  1
# 9          1       2  14.0      1      0  30.0708     0  0  0
# 10         1       3   4.0      1      1  16.7000     0  0  1
# 11         1       1  58.0      0      0  26.5500     0  0  1
# 12         0       3  20.0      0      0   8.0500     1  0  1
# 13         0       3  39.0      1      5  31.2750     1  0  1
# ...

# %%
df.drop('Survived',axis=1).head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0       3  22.0      1      0   7.2500     1  0  1
# 1       1  38.0      1      0  71.2833     0  0  0
# 2       3  26.0      0      0   7.9250     0  0  1
# 3       1  35.0      1      0  53.1000     0  0  1
# 4       3  35.0      0      0   8.0500     1  0  1

# %%
df[['Survived']].head()
# Out:
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('Survived',axis=1),df[['Survived']],test_size=0.30,
                                                   random_state=101)

# %%
x_train
# Out:
#      Pclass   Age  SibSp  Parch      Fare  male  Q  S
# 520       1  30.0      0      0   93.5000     0  0  1
# 510       3  29.0      0      0    7.7500     1  1  0
# 446       2  13.0      0      1   19.5000     0  0  1
# 2         3  26.0      0      0    7.9250     0  0  1
# 691       3   4.0      0      1   13.4167     0  0  0
# ..      ...   ...    ...    ...       ...   ... .. ..
# 575       3  19.0      0      0   14.5000     1  0  1
# 838       3  32.0      0      0   56.4958     1  0  1
# 337       1  41.0      0      0  134.5000     0  0  0
# 523       1  44.0      0      1   57.9792     0  0  0
# 863       3  24.0      8      2   69.5500     0  0  1
#
# [623 rows x 8 columns]

# %%
x_test
# Out:
#      Pclass   Age  SibSp  Parch      Fare  male  Q  S
# 331       1  45.5      0      0   28.5000     1  0  1
# 700       1  18.0      1      0  227.5250     0  0  0
# 748       1  19.0      1      0   53.1000     1  0  1
# 751       3   6.0      0      1   12.4750     1  0  1
# 481       2  29.0      0      0    0.0000     1  0  1
# ..      ...   ...    ...    ...       ...   ... .. ..
# 388       3  24.0      0      0    7.7292     1  1  0
# 416       2  34.0      1      1   32.5000     0  0  1
# 407       2   3.0      1      1   18.7500     1  0  1
# 482       3  50.0      0      0    8.0500     1  0  1
# 829       1  62.0      0      0   80.0000     0  0  0
#
# [268 rows x 8 columns]

# %%
y_train
# Out:
#      Survived
# 520         1
# 510         1
# 446         1
# 2           1
# 691         1
# ..        ...
# 575         0
# 838         1
# 337         1
# 523         1
# 863         0
#
# [623 rows x 1 columns]

# %%
y_test
# Out:
#      Survived
# 331         0
# 700         1
# 748         0
# 751         1
# 481         0
# ..        ...
# 388         0
# 416         1
# 407         1
# 482         0
# 829         1
#
# [268 rows x 1 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()
LR.fit(x_train,y_train)
# Out:
# /Library/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = LR.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix , accuracy_score

# %%
cf = confusion_matrix(y_test,y_pred)

# %%
print(cf)
# Out:
# [[133  21]
#  [ 38  76]]

# %%
ac = accuracy_score(y_test, y_pred)

# %%
print(ac)
# Out:
# 0.7798507462686567

# %% [markdown]
# # another example of exploratory data analysis By using SweetViz library

# %%
import pandas as pd
import sweetviz
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
my_report = sweetviz.analyze([train, "Train"],target_feat='SalePrice')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
my_report.show_html('Report.html')
# Out:
# Report Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
my_report1 = sweetviz.compare([train, "Train"],[test, "Test"],target_feat='SalePrice')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
my_report1.show_html('Report_compare.html')
# Out:
# Report Report_compare.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # another example of exploratory data analysis By using Pandas Profiling library

# %%
import pandas as pd
from pandas_profiling import ProfileReport
from sklearn.datasets import load_diabetes

# %%
diab_data=load_diabetes()

# %%
df=pd.DataFrame(data=diab_data.data,columns=diab_data.feature_names)

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
### To Create the Simple report quickly
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# %%
profile.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# <ipython-input-31-1055f09e4b48> in <module>
# ----> 1 profile.to_widgets()
#
# /Library/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in to_widgets(self)
#     412         from IPython.core.display import display
#     413
# --> 414         display(self.widgets)
#     415
#     416     def _repr_html_(self) -> None:
#
# /Library/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in widgets(self)
#     195     def widgets(self) -> Renderable:
#     196         if self._widgets is None:
# --> 197             self._widgets = self._render_widgets()
#     198         return self._widgets
#     199
#
# /Library/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in _render_widgets(self)
# ...

# %%
profile.to_file("output.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # another example Titanic Dataset¶ by using pandas profiling

# %%
df=pd.read_csv('titanic_train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
### To Create the Simple report quickly
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# %%
profile.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# <ipython-input-35-1055f09e4b48> in <module>
# ----> 1 profile.to_widgets()
#
# /Library/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in to_widgets(self)
#     412         from IPython.core.display import display
#     413
# --> 414         display(self.widgets)
#     415
#     416     def _repr_html_(self) -> None:
#
# /Library/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in widgets(self)
#     195     def widgets(self) -> Renderable:
#     196         if self._widgets is None:
# --> 197             self._widgets = self._render_widgets()
#     198         return self._widgets
#     199
#
# /Library/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in _render_widgets(self)
# ...

# %%
profile.to_file("output1.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # another exploratory data Analysis example by using Pandas Visual Analysis library ¶

# %%
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from pandas_visual_analysis import VisualAnalysis

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(df['sepal_length'],df['petal_width'])

# %%
VisualAnalysis(df)

# %% [markdown]
# # another exploratory data Analysis example by using D-Tale library ¶

# %%
import seaborn as sns

# %%
df=sns.load_dataset('planets')

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
import dtale

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Taruns-MacBook-Air.local:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import numpy as np
import pandas as pd

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

chart = np.histogram(df[~pd.isnull(df['distance'])][['distance']], bins=20)
# main statistics
stats = df['distance'].describe().to_frame().T

# %%
stats
# Out:
#           count        mean         std   min    25%    50%    75%     max
# distance  808.0  264.069282  733.116493  1.35  32.56  55.25  178.5  8500.0

# %%
df.corr()
# Out:
#                   number  orbital_period      mass  distance      year
# number          1.000000       -0.012570 -0.241429 -0.033638  0.147849
# orbital_period -0.012570        1.000000  0.173725 -0.034365 -0.032333
# mass           -0.241429        0.173725  1.000000  0.274082 -0.123787
# distance       -0.033638       -0.034365  0.274082  1.000000  0.178922
# year            0.147849       -0.032333 -0.123787  0.178922  1.000000

# %%
#
s = df['distance']
q1 = s.quantile(0.25)
q3 = s.quantile(0.75)
iqr = q3 - q1
iqr_lower = q1 - 1.5 * iqr
iqr_upper = q3 + 1.5 * iqr
outliers = dict(s[(s < iqr_lower) | (s > iqr_upper)])

# %%
outliers
# Out:
# {39: 500.0,
#  40: 500.0,
#  93: 680.0,
#  100: 460.0,
#  102: 560.0,
#  103: 1150.0,
#  104: 1060.0,
#  105: 1340.0,
#  106: 840.0,
#  107: 920.0,
#  108: 870.0,
#  109: 770.0,
#  110: 1230.0,
#  111: 600.0,
#  158: 480.0,
#  185: 535.0,
#  187: 411.0,
#  189: 642.0,
#  190: 501.0,
#  192: 447.0,
#  193: 542.0,
#  197: 453.0,
#  654: 550.0,
#  658: 1330.0,
#  659: 650.0,
#  660: 650.0,
#  661: 650.0,
#  664: 613.0,
#  665: 613.0,
#  666: 613.0,
#  667: 613.0,
#  668: 613.0,
#  669: 613.0,
#  670: 600.0,
#  672: 980.0,
#  675: 800.0,
#  679: 2119.0,
#  680: 2119.0,
#  688: 800.0,
#  689: 800.0,
#  690: 1200.0,
#  691: 1200.0,
#  701: 1400.0,
#  702: 1400.0,
#  703: 1400.0,
#  704: 1400.0,
#  705: 1400.0,
#  706: 2100.0,
#  707: 2100.0,
#  718: 1499.0,
#  719: 1645.0,
#  720: 470.0,
#  721: 470.0,
#  725: 600.0,
#  726: 1200.0,
#  727: 2700.0,
#  728: 770.0,
#  732: 1950.0,
#  733: 2250.0,
#  735: 855.0,
#  736: 855.0,
#  737: 1500.0,
#  738: 1500.0,
#  776: 1000.0,
#  780: 1107.0,
# ...
